# %%
import os
# 该文件用于求取同一官能团下不同吸收的区间并集

# %%
#求两个区间的并集
def get_union(rangea, rangeb):
    rangea_lower, rangea_upper = rangea
    rangeb_lower, rangeb_upper = rangeb
    if rangea_upper + 1 == rangeb_lower:
        return [1, rangea_lower, rangeb_upper]
    if rangea_upper < rangeb_lower:
        return [2, rangea, rangeb]
    if rangea_lower <= rangeb_lower and rangea_upper >= rangeb_upper:
        return [1, rangea_lower, rangea_upper]
    elif rangea_lower <= rangeb_lower and rangea_upper < rangeb_upper:
        return [1, rangea_lower, rangeb_upper]



def get_nset_union(section_lists):
    section_lists.sort(key=lambda range_item: range_item[0])
    i, j = 0, len(section_lists) - 1
    while True:
        if i == j:
            break
        rangea, rangeb = section_lists.pop(i),  section_lists.pop(i)
        union_item = get_union(rangea, rangeb)
        if union_item[0] == 1:
            section_lists.insert(i, [union_item[1], union_item[2]])
        elif union_item[0] == 2:
            section_lists.insert(i, union_item[1])
            section_lists.insert(i + 1, union_item[2])
            i = i + 1
        j = len(section_lists) - 1
    return section_lists

# %%
# 测试
section_lists = [[1, 3], [5, 6], [7, 9], [12, 15], [13, 17], [13, 20], [22, 23], [25, 28], [30, 33], [35, 38], [38,42], [39, 45]]
print(get_nset_union(section_lists))
# Out:
# [[1, 3], [5, 9], [12, 20], [22, 23], [25, 28], [30, 33], [35, 45]]

# %% [markdown]
# 含硫化合物

# %%
#name = ['硫醇','二硫化合物','直链R—S—S—R'...]
# 从左侧的表格里生成如下数据：
range = [[[2600,2500],[5000],[2700,2630]],
        [[1420,1450]],
        [[525,510]],
        [[510]],
        [[545]],
        [[540,520]],
        [[1150]],
        [[1225,1140]],
        [[1155,1140]],
        [[1060,1050],[850],[700],[500]],
        [[1235,1210]],
        [[1220]],
        [[1225,1185]],
        [[870]],
        [[1200,1100]],
        [[1060,1040]],
        [[1100,1000]],
        [[1570,1395]],
        [[1420,1260],[1140,940],[850,680]],
        [[1300,1100]],
        [[1060,1040]],
        [[1090]],
        [[1135,1125]],
        [[1215,1150]],
        [[1150]],
        [[1350,1290],[1160,1120]],
        [[1352,1342]],
        [[1165,1150],[1380,1310]],
        [[1180,1140],[1370,1355]],
        [[1175,1165],[1390,1360]],
        [[1185,1168],[1415,1390]],
        [[1200,1187],[1192,1175]]         
         
         
         
         ]

# s_dict = {'name':[], 'range':[]}

# %%
# 将range里面的列表重构成一个列表
range_list = []
for item in range:
    for sub_item in item:
        # 颠倒顺序
        sub_item.reverse()
        range_list.append(sub_item)

# %%
# 取出range_list里面只有一个数的列表，并从range_list里面删除
single_list = []
double_list = []
for item in range_list:
    if len(item) == 1:
        single_list.append(item)
    else:
        double_list.append(item)

print(get_nset_union(double_list))
print(single_list)
# Out:
# [[510, 540], [680, 850], [940, 1570], [2500, 2600], [2630, 2700]]
# [[5000], [510], [545], [1150], [850], [700], [500], [1220], [870], [1090], [1150]]

# %% [markdown]
# 含氧化合物

# %%
#name = ['硫醇','二硫化合物','直链R—S—S—R'...]
# 从左侧的表格里生成如下数据：
range = [#醇和酚
        [[3670,3580]],
        [[3550,3230]],
        [[1790,1770]],
        [[1750,1735]],
        [[1790,1775],[1765,1740]],
        [[1815,1785]],
        [[1745,1730]],
        [[1775,1740],[1740,1715]],
        [[1820,1800]],
        [[1775,1710],[1290,1280],[1120,1100],[1020,1010],[515,490],[490,470]],
        [[1370,1160]],
        [[1760,1740]],
        [[1790,1755]],
        [[1820,1775]],
        [[1860,1750]],
        [[1770]],
        [[1780,1760]],
        [[1770]],
        ## 酰卤
        [[1815,1770]],
        [[1780,1750]],
        # 酸酐
        [[1860,1800]],
        [[1800,1740]],
        [[1830,1780]],
        [[1755,1710]],
        [[1820,1780],[1780,1740]],
        [[1870,1820],[1800,1755]],
        [[1860,1850],[1780,1760]],
        [[1820,1750]],
        [[1900,1870]],
        [[1820,1810],[1800,1760]],
        [[1800,1780],[1780,1760]],
        [[1850,1790]],
        [[1850],[1770]],
        [[1785],[1725]],
        # 酰胺
        [[3500,3400],[3350],[3180]],
        [[1690],[1650]],
        [[1620,1590],[1650,1610]],
        [[1430,1400],[1430,1400]],
        [[700]],
        [[3500,3400],[3320,3060]],
        [[3460,3400],[3320,3070]],
        [[3440,3420],[3180,3140]],
        [[3100,3070],[3100,3070]],
        [[1700,1670],[1680,1630]],
        [[1550,1510],[1570,1510]],
        [[1430]],
        [[1260],[1335,1200]],
        [[700]],
        [[1670,1630]],
        [[1680]],
        [[1710,1700]],
        [[1760,1730]],
        [[1790,1720],[1710,1670]],
        [[1790,1735],[1745,1680]],
        [[1670,1650]],
        [[1740,1690]],
        ## 氨基酸
        [[3130,3030]],
        [[3000,2750]],
        [[2700]],
        [[2760,2530]],
        [[1660,1590]],
        [[1550,1480]],
        [[1600,1560]],
        [[1470,1370]],
        [[3130,3030]],
        [[3030,2500],[2000]],
        [[1660,1590]],
        [[1550,1480]],
        [[1755,1700]],
        [[1220,1190]],
        [[3500,3200]],
        [[1600,1560]],
        [[1420,1300]]

         ]

# s_dict = {'name':[], 'range':[]}

# %%
# 将range里面的列表重构成一个列表
range_list = []
for item in range:
    for sub_item in item:
        # 颠倒顺序
        sub_item.reverse()
        range_list.append(sub_item)

# %%
# 取出range_list里面只有一个数的列表，并从range_list里面删除
single_list = []
double_list = []
for item in range_list:
    if len(item) == 1:
        single_list.append(item)
    else:
        double_list.append(item)

print(get_nset_union(double_list))
print(single_list)
# Out:
# [[375, 450], [470, 515], [600, 720], [750, 770], [785, 1470], [1480, 1900], [2400, 3670]]
# [[3760], [3280], [3100], [675], [1050], [1035], [1020], [1015], [1085], [1070], [1010], [1050], [1135], [1120], [1120], [1060], [1010], [1320], [1660], [1110], [1030], [1000], [3450], [1175], [3450], [1690], [1705], [1715], [1745], [1780], [1815], [1720], [1630], [1748], [1742], [1762], [1748], [1742], [1762], [1745], [1800], [1410], [1720], [1720], [1650], [1770], [1770], [1850], [1770], [1785], [1725], [3350], [3180], [1690], [1650], [700], [1430], [1260], [700], [1680], [2700], [2000]]

# %% [markdown]
# 含氮化合物

# %%
#name = ['硫醇','二硫化合物','直链R—S—S—R'...]
# 从左侧的表格里生成如下数据：
range = [## 肟,亚胺,醚
        [[1690,1650]],
        [[1650,1620],[1660,1480]],
        [[1650,1640]],
        [[1635,1620]],
        [[1690,1630]],
        [[1645,1605]],
        [[1725,1625]],
        [[1670,1600]],
        [[1630,1590]],
        [[1600,1530]],
        [[1685,1580]],
        [[1690,1645]],
        [[1640,1605]],
        [[1620,1550]],
        [[3650,3500],[3300,3130],[1475,1315],[960,930]],
        [[3540,2700],[1670,1620]],
        [[1560,1520]],
        [[3400,3300],[3400,3100]],
        [[2600,2400]],
        ## 偶氮化合物
        [[1575,1555]],
        [[1500]],
        [[1440,1410]],
        [[1510]],
        [[1530,1495]],
        [[1345,1285]],
        [[1480,1450]],
        [[1340,1315],[1465,1445]],
        [[1070,1055]],
        [[1620]],
        ## 硝基，亚硝基化合物
        [[1575,1500],[1380,1300],[920,830]],
        [[1565,1530],[1380,1340]],
        [[1580,1570],[1360,1340]],
        [[1600,1570],[1337,1327]],
        [[1625,1595],[1315,1305]],
        [[1530,1510],[1355,1335]],
        [[1550,1500]],
        [[1365,1335]],
        [[1650,1600],[1300,1250]],
        [[1630,1530],[1312,1250]],
        [[1600]],
        [[1500]],
        [[1290,1190]],
        [[1425,1380]],
        [[1680,1610]],
        [[1500,1430]],
        ## 胺，胺盐和亚胺盐
        [[3550,3330],[3450,3250]],
        [[3450,3250]],
        [[3500,3300]],
        [[3450,3400]],
        [[2600,2400]],
        [[3360,3340],[3280,3270]],
        [[3400,3300]],
        [[1650,1580],[900,650]],
        [[850,810]],
        [[795,760]],
        [[830]],
        [[795]],
        [[1580,1490],[750,700]],
        [[750,710]],
        [[735,700]],
        [[1590,1500]],
        [[1090,1020]],
        [[1090,1065]],
        [[1140,1080]],
        [[1045,1035]],
        [[1240,1170]],
        [[1040,1020]],
        [[1190,1170],[1145,1130]],
        [[1145,1130]],
        [[1190,1170]],
        [[1230,1030]],
        [[1210,1150]],
        [[1100,1030]],
        [[1270]],
        [[1190],[1040]],
        [[1205]],
        [[1070]],
        [[1360,1250]],
        [[1380,1330]],
        [[1690,1640]],
        [[2820,2760]],
        [[1370,1310]],
        [[495,445],[290]],
        [[445,345]],
        [[455,405]],
        [[510,480]],
        [[1680,1630]],
        [[3350,3100]],
        [[2700,2250]],
        [[3380],[3280]],
        [[3000,2700]],
        [[2200,1800]],
        [[2700,2330]],
        [[3300,3030]],
        [[2500],[2000],[1625,1560],[1550,1500],[800]],
        [[2000],[1620,1560],[800]],
        [[2200,1800],[1680]],
        [[1430,1390]]

        ]

# %%
# 将range里面的列表重构成一个列表
range_list = []
for item in range:
    for sub_item in item:
        # 颠倒顺序
        sub_item.reverse()
        range_list.append(sub_item)

# %%
# 取出range_list里面只有一个数的列表，并从range_list里面删除
single_list = []
double_list = []
for item in range_list:
    if len(item) == 1:
        single_list.append(item)
    else:
        double_list.append(item)

print(get_nset_union(double_list))
print(single_list)
# Out:
# [[345, 510], [650, 920], [930, 960], [1020, 1725], [1800, 2200], [2250, 3650]]
# [[1500], [1510], [1620], [1600], [1500], [830], [795], [1270], [1190], [1040], [1205], [1070], [290], [3380], [3280], [2500], [2000], [800], [2000], [800], [1680]]

# %% [markdown]
# 含卤素基团

# %%
#name = ['硫醇','二硫化合物','直链R—S—S—R'...]
# 从左侧的表格里生成如下数据：
range = [## 有机氪化物
        [[1400,1000],[830,520]],
        [[1110,1000],[780,680]],
        [[1250,1050]],
        [[1360,1090]],
        [[1365,1325],[745,730]],
        [[1350,1120],[780,680],[680,590],[600,540],[555,505],[460,200]],
        [[1350,1140]],
        [[1755,1735],[525,505],[515,355],[455,345]],
        [[1800,1780],[1340,1300]],
        [[1330,1310]],
        [[600,580]],
        ## 有机氯化物
        [[760,505],[450,250]],
        [[730,720],[655,645]],
        [[680,670],[625],[615,610]],
        [[630,610]],
        [[580,560]],
        [[800,700]],
        [[500,320],[265,235],[260,180]],
        [[690],[485,470]],
        [[580],[350,340]],
        [[805,690]],
        [[780,740]],
        [[730,580]],
        [[730,720],[660,650],[685,680]],
        [[760],[675,655],[640,625],[615,605]],
        [[580,560],[635,610]],
        ## 有机溴化物
        [[650,485],[300,140]],
        [[645,635],[565,555],[440,430]],
        [[645,635],[565,555],[490,480],[445,425]],
        [[650,645],[620,610],[515,500]],
        [[620,605],[590,575],[540,530]],
        [[600,595],[525,505]],
        [[310,250],[185,135],[160,120]],
        [[750,685]],
        [[690,550]],
        ## 有机碘化物
        [[600,200],[300,50]],
        [[600,585],[515,500]],
        [[595],[500]],
        [[575],[550,520],[490,480]],
        [[580,560],[510,485],[485,465]],
        [[200],[100],[50]],
        [[655]],
        [[640]],
        ## 芳香族卤化物
        [[1050]],
        [[1270,1100]],
        [[680,520],[420,375],[340,240]],
        [[1060,1035],[1080,1075],[1100,1090],[760,395],[500,370],[390,165],[330,230]],
        [[1045,1025],[1075,1065],[400,260],[325,175],[290,225]],
        [[1060,1055],[310,160],[265,185],[200]]


]

# %%
# 将range里面的列表重构成一个列表
range_list = []
for item in range:
    for sub_item in item:
        # 颠倒顺序
        sub_item.reverse()
        range_list.append(sub_item)

# %%
# 取出range_list里面只有一个数的列表，并从range_list里面删除
single_list = []
double_list = []
for item in range_list:
    if len(item) == 1:
        single_list.append(item)
    else:
        double_list.append(item)

print(get_nset_union(double_list))
print(single_list)
# Out:
# [[50, 830], [1000, 1400], [1735, 1755], [1780, 1800]]
# [[625], [690], [580], [760], [595], [500], [575], [200], [100], [50], [655], [640], [1050], [200]]

# %% [markdown]
# 含磷基团

# %%
#name = ['硫醇','二硫化合物','直链R—S—S—R'...]
# 从左侧的表格里生成如下数据：
range = [## 有机氪化物
        [[2455,2265],[1150,965]],
        [[2285,2265],[1100,1085],[1065,1040],[940,910]],
        [[2285,2270],[1100,1085]],
        [[2455,2400]],
        [[2340,2280],[990,965]],
        [[950,910]],
        [[980,960]],
        [[1795,1650],[745,615]],
        [[795,650]],
        [[1430,1390],[1345,1275],[980,840]],
        [[790,770],[850,840]],
        [[960,835]],
        [[1285,1270],[870,865]],
        [[1300,1295],[850,840]],
        [[1320,1305],[930,885],[1310,1280],[900,875]],
        [[1315,1300],[925,885]],
        [[1285,1225]],
        [[845,780],[770,720]],
        [[1440,1405],[780,760]],
        [[795,740]],
        [[1140,1050],[570,545]],
        [[1215,1110]],
        [[660,575]],
        [[1300,1150]],
        [[1030,970],[990,920]],
        [[1100,1000]],
        [[585,545]],
        [[770,760]],
        [[930,805]],
        [[835,805]],
        [[930,895]],
        [[605,435]],
        [[485,400]],
        [[590,485],[545,420]],
        [[565,440]],
        [[540,435]],
        [[550,525],[525,490]],
        [[1050,970],[565,550],[490,440]],
        [[1025,870]],
        [[500],[495,460]],
        [[930,815],[765,700]],
        [[1070,855]],
        [[1645,1595]],
        [[1660,1630]],
        [[2220,2180]]



        ]

# %%
# 将range里面的列表重构成一个列表
range_list = []
for item in range:
    for sub_item in item:
        # 颠倒顺序
        sub_item.reverse()
        range_list.append(sub_item)

# %%
# 取出range_list里面只有一个数的列表，并从range_list里面删除
single_list = []
double_list = []
for item in range_list:
    if len(item) == 1:
        single_list.append(item)
    else:
        double_list.append(item)

print(get_nset_union(double_list))
print(single_list)
# Out:
# [[290, 1500], [1595, 1795], [2080, 2455], [2525, 2725], [3000, 3100]]
# [[3050], [1600], [1500], [1250], [460], [1250], [1155], [1215], [1235], [1250], [1200], [1210], [1200], [590], [560], [590], [570], [535], [500]]

# %% [markdown]
# 金属及半金属基团

# %%
#name = ['硫醇','二硫化合物','直链R—S—S—R'...]
# 从左侧的表格里生成如下数据：
range = [## 硅基
        [[2250,2100],[985,800]],
        [[2160,2140],[945,910],[685,540]],
        [[2150,2115],[945,920],[895,840],[745,625],[600,460]],
        [[2135,2095],[845,800]],
        [[1690,1570],[710,665]],
        [[1280,1240],[850,800],[760,750]],
        [[1280,1250]],
        [[860,760]],
        [[765]],
        [[855],[815,800]],
        [[840],[765],[330,240]],
        [[1250,1220],[1020,1000],[970,945]],
        [[1250,1175],[760,670]],
        [[1925],[1610,1590],[1410,1390],[1010,1000],[980,940],[580,515]],
        [[3080,3030],[1600],[1480,1425],[1125,1090],[730]],
        [[700,690],[670,625],[490,445],[405,345],[290]],
        [[635,605],[495,470],[445,400],[380,305]],
        [[625,605],[515,485],[445,420],[330]],
        [[495,480]],
        [[3700,3200],[955,835]],
        [[1620]],
        [[1110,1000]],
        [[2860],[1190],[1100],[850,800]],
        [[390,360]],
        [[480,440],[470,330]],
        [[1190,1140],[1100,1070],[990,945]],
        [[475,405]],
        [[500,440]],
        [[1135,1090],[970,920]],
        [[1090,1020]],
        [[625,480]],
        [[850,840]],
        [[810,800]],
        [[820,780]],
        [[3570,3475],[3410,3390],[1550,1530]],
        [[3400],[1175],[935]],
        [[880,835]],
        [[800,785]],
        [[920,820]],
        [[945,915],[910,870]],
        [[980,945],[910,860]],
        [[550,470]],
        [[595,535],[540,460]],
        [[625,570],[535,450]],
        [[430,360]],
        [[460,425],[395,330]],
        [[480,450],[360,300]],
        [[365,280]],
        [[390,330],[325,275]],
        [[410,365],[280,220]],
        [[1125,1090]],
        [[1080]],
        [[1080,1050]],
        [[1050]],
        [[900,700]],
        [[780,580]],
        [[625]]

        ]

# %%
# 将range里面的列表重构成一个列表
range_list = []
for item in range:
    for sub_item in item:
        # 颠倒顺序
        sub_item.reverse()
        range_list.append(sub_item)

# %%
# 取出range_list里面只有一个数的列表，并从range_list里面删除
single_list = []
double_list = []
for item in range_list:
    if len(item) == 1:
        single_list.append(item)
    else:
        double_list.append(item)

print(get_nset_union(double_list))
print(single_list)
# Out:
# [[220, 990], [1000, 1135], [1140, 1280], [1390, 1410], [1425, 1480], [1530, 1550], [1570, 1690], [2095, 2250], [3030, 3080], [3200, 3700]]
# [[765], [855], [840], [765], [1925], [1600], [730], [290], [330], [1620], [2860], [1190], [1100], [3400], [1175], [935], [1080], [1050], [625]]

# %% [markdown]
# 含硼基团

# %%
#name = ['硫醇','二硫化合物','直链R—S—S—R'...]
# 从左侧的表格里生成如下数据：
range = [## 硼
        [[2565,2480],[1180,1110],[920,900]],
        [[2640,2570],[2535,2485],[1205,1140],[975,920]],
        [[2140,2080]],
        [[1990,1850],[1800,1710],[1610,1540]],
        [[2380,2315],[2285,2265],[1165]],
        [[2310,2195]],
        [[1270,620]],
        [[1380,1310]],
        [[1350,1310]],
        [[1435,1425],[1330,1310],[1180,1120],[675,600]],
        [[1350,1310],[1500,1435]],
        [[1330,1310]],
        [[1380,1335],[1225,1080]],
        [[1470,1180]],
        [[1360,1330],[1240,1235],[1075,1065]],
        [[1390,1355],[1255,1145]],
        [[1280,1200],[900]],
        [[1510,1400],[720,635]],
        [[1500,840]],
        [[1500,1410],[1300,1200]],
        [[1360,1300]],
        [[1260,1125],[1030,800]],
        [[1030]],
        [[955,905]]

        ]

# %%
# 将range里面的列表重构成一个列表
range_list = []
for item in range:
    for sub_item in item:
        # 颠倒顺序
        sub_item.reverse()
        range_list.append(sub_item)

# %%
# 取出range_list里面只有一个数的列表，并从range_list里面删除
single_list = []
double_list = []
for item in range_list:
    if len(item) == 1:
        single_list.append(item)
    else:
        double_list.append(item)

print(get_nset_union(double_list))
print(single_list)
# Out:
# [[600, 1510], [1540, 1610], [1710, 1800], [1850, 1990], [2080, 2140], [2195, 2310], [2315, 2380], [2480, 2565], [2570, 2640]]
# [[1165], [900], [1030]]

# %% [markdown]
# 碳氢化合物

# %%
#name = ['硫醇','二硫化合物','直链R—S—S—R'...]
# 从左侧的表格里生成如下数据：
range = [## 链烷烃和环烷烃
        [[2975,2950]],
        [[2885,2865],[2940,2915],[2870,2840]],
        [[2890,2880]],
        [[2985,2965],[2955,2935],[2930,2920],[2870,2860],[2830,2740]],
        [[3100,3070],[3035,2995]],
        [[3000,2975],[2925,2875]],
        [[2960,2950],[2870,2850]],
        [[1465,1440],[1390,1370]],
        [[1385,1380]],
        [[1370,1365],[1395,1385],[1370,1365]],
        [[1480,1440]],
        [[1340]],
        [[725,720]],
        [[735,725]],
        [[745,735]],
        [[785,770]],
        [[1175,1165],[1150,1130],[840,790],[495,490]],
        [[1255,1245],[1225,1165]],
        [[510,505]],
        [[540,485],[455]],
        [[570,445]],
        [[560,540],[470,445]],
        [[555,535]],
        [[530]],
        [[490]],
        [[515]],
        [[390,260]],
        [[560,540]],
        [[545,520]],
        [[585,565]],
        [[1030,1000],[870,850],[540,500]],
        [[1000,960],[930,890],[580,490]],
        [[630,575],[500,475]],
        [[580,515],[500,480],[455,370]],
        [[560,530],[470,435]],
        [[570,515]],
        [[525,470],[450,395],[550]],
        ## 炔烃
        [[3340,3330]],
        [[2140,2100]],
        [[2260,2190]],
        [[2270,2220],[2250]],
        [[1375,1225]],
        [[695,575]],
        [[630]],
        [[355,335]],
        [[510,260]],
        [[520,495]],
        [[495,480]],
        [[475,465]],
        [[550],[350]],
        [[185,160]],
        ## 芳香烃
        [[3080,3010]],
        [[1625,1590],[1590,1575],[1520,1470],[1465,1430]],
        [[770,730],[710,690]],
        [[770,735]],
        [[810,750],[710,690]],
        [[860,800]],
        [[900,860]]
        ]

# %%
# 将range里面的列表重构成一个列表
range_list = []
for item in range:
    for sub_item in item:
        # 颠倒顺序
        sub_item.reverse()
        range_list.append(sub_item)

# %%
# 取出range_list里面只有一个数的列表，并从range_list里面删除
single_list = []
double_list = []
for item in range_list:
    if len(item) == 1:
        single_list.append(item)
    else:
        double_list.append(item)

print(get_nset_union(double_list))
print(single_list)
# Out:
# [[160, 185], [260, 1055], [1130, 1530], [1575, 1700], [1730, 1850], [1865, 1900], [1970, 1985], [2100, 2140], [2190, 2270], [2710, 2835], [2840, 3100], [3330, 3340]]
# [[1340], [455], [530], [490], [515], [3050], [3050], [1030], [1200], [1500], [1440], [1475], [1355], [1305], [1250], [1280], [1250], [1630], [1655], [1565], [1610], [1645], [1650], [1685], [1680], [1655], [1650], [1645], [1630], [930], [930], [990], [765], [790], [635], [550], [550], [2250], [630], [550], [350]]

# %% [markdown]
# 合并分区评估

# %%
select_range = [[[3550,3330],[3450,3250]],
        [[3450,3250]],
        [[3500,3300]],
        [[3450,3400]],
        #[[2600,2400]],
        [[3360,3340],[3280,3270]],
        [[3400,3300]],
        ##
        [[1650,1580],[900,650]],
        [[850,810]],
        [[795,760]],
        [[830]],
        [[795]],
        [[1580,1490],[750,700]],
        [[750,710]],
        [[735,700]],
        #[[1590,1500]],
        ##
        [[1090,1020]],
        [[1090,1065]],
        [[1140,1080]],
        [[1045,1035]],
        [[1240,1170]],
        [[1040,1020]],
        [[1190,1170],[1145,1130]],
        [[1145,1130]],
        [[1190,1170]],
        [[1230,1030]],
        [[1210,1150]],
        [[1100,1030]],
        [[1270]],
        [[1190],[1040]],
        [[1205]],
        [[1070]],
        [[1360,1250]],
        [[1380,1330]],
        #[[1690,1640]],
        ##
        #[[2820,2760]], ##
        #[[1370,1310]],
        #[[495,445],[290]],
        #[[445,345]],
        #[[455,405]],
        #[[510,480]],
        #[[1680,1630]], ## 
        ##
        #[[3350,3100]],
        #[[2700,2250]],
        #[[3380],[3280]],
        #[[3000,2700]],
        #[[2200,1800]],
        #[[2700,2330]],
        #[[3300,3030]],
        ##
        [[2500],[2000],[1625,1560],[1550,1500],[800]],
        [[2000],[1620,1560],[800]],
        #[[2200,1800],[1680]],
        #[[1430,1390]]
        ]

# 将range里面的列表重构成一个列表
range_list = []
for item in select_range:
    for sub_item in item:
        # 颠倒顺序
        sub_item.reverse()
        range_list.append(sub_item)

# 取出range_list里面只有一个数的列表，并从range_list里面删除
single_list = []
double_list = []
for item in range_list:
    if len(item) == 1:
        single_list.append(item)
    else:
        double_list.append(item)

print(get_nset_union(double_list))
print(single_list)
# Out:
# [[650, 900], [1020, 1240], [1250, 1380], [1490, 1650], [3250, 3550]]
# [[830], [795], [1270], [1190], [1040], [1205], [1070], [2500], [2000], [800], [2000], [800]]

# %%
# 炔烃
select_range = [# 炔烃C-H伸缩振动，C*C伸缩振动
       [[3620,3590]],
        [[3250,3000]],
        [[3200,2500]],
        [[1390,1330],[1260,1180]],
        [[1360,1300],[1225,1150]],
        [[1320],[1255,1240]],
        [[1175,1150],[1285,1270],[1190,1180],[1160,1150]],
        [[1260,1245],[1175,1165]],
        [[1660],[1110],[720,600],[450,375]]

        ]

# 将range里面的列表重构成一个列表
range_list = []
for item in select_range:
    for sub_item in item:
        # 颠倒顺序
        sub_item.reverse()
        range_list.append(sub_item)

# 取出range_list里面只有一个数的列表，并从range_list里面删除
single_list = []
double_list = []
for item in range_list:
    if len(item) == 1:
        single_list.append(item)
    else:
        double_list.append(item)

print(get_nset_union(double_list))
print(single_list)
# Out:
# [[375, 450], [600, 720], [1150, 1260], [1270, 1285], [1300, 1390], [2500, 3250], [3590, 3620]]
# [[1320], [1660], [1110]]

# %%
# 烯烃
select_range = [# 烯烃C-C伸缩振动
        [[1680,1620]],
        [[1640,1610]],
        [[1660,1580]],
        [[1620,1610]],
        [[1645,1640]],
        [[1620,1595]],
        [[1640,1630],[1620,1610]],
        [[1620,1615]],
        [[1700,1645]],
        [[1640,1635],[1625,1620]],
        [[1665,1635]],
        [[1675,1665]],
        [[1660,1664]],
        [[1630,1620]],
        [[1630]],
        [[1675,1670]],
        [[1700,1660]],
        [[1690,1665]],
        [[1650,1645]],
        [[1800,1780]],
        [[1755,1735]],
        [[1680,1630]],
        [[1690,1670]],
        [[1655]],
        [[1565]],
        [[1610]],
        [[1645]],
        [[1650]],
        #[[1900,1865]],
        [[1685]],
        [[1685,1670]],
        [[1685,1675]],
        [[1780,1730]],
        [[1680]],
        [[1655]],
        [[1650]],
        [[1645]],
        [[1630]],
        [[1650,1580]],
        [[1530,1500]],
        ## C-H伸缩振动和变形振动
        [[3095,3075],[3030,2995],
         #[1985,1970],[1850,1800],
         #[1420,1410],[1300,1290],
         [995,980],[915,905]],
        [[945,925],[905,865]],
        [[965,960],[945,940],[820,810]],
        [[995,980],[965,955]],
        [[950,935],[870,850]],
        [[985,980],[965,960]],
        [[3095,3075],[2985,2970],
         #[1800,1780]
         ],
        #[[1420,1410],[1320,1290],[895,885]],
        [[880,865]],
        [[930,895]],
        [[930]],
        [[880,865]],
        [[3040,3010],
         #[1420,1400],
         [730,665]],
        [[780,770]],
        [[3040,3010],
         #[1325,1290],
         [980,955]],
        [[930]],
        [[990]],
        [[940,920]],
        [[3040,3010],
         #[1680,1600],
         #[1350,1340],
         [850,790]],
        [[3060,2995],[780,665]],
        #[[1410,1390],[1265,1245],[1010,985],[960,940]],
        [[765]],
        [[790]],
        ## 骨架振动
        # [[635],[550],[485,445]],
        # [[670,455]],
        # [[455,370]],
        # [[490,465]],
        # [[325,285]],
        # [[630,575],[500,475]],
        # [[580,515],[500,480],[455,370]],
        # [[560,530],[470,435]],
        # [[570,515]],
        # [[525,470],[450,395],[550]],

        ]

# 将range里面的列表重构成一个列表
range_list = []
for item in select_range:
    for sub_item in item:
        # 颠倒顺序
        sub_item.reverse()
        range_list.append(sub_item)

# 取出range_list里面只有一个数的列表，并从range_list里面删除
single_list = []
double_list = []
for item in range_list:
    if len(item) == 1:
        single_list.append(item)
    else:
        double_list.append(item)

print(get_nset_union(double_list))
print(single_list)
# Out:
# [[665, 780], [790, 950], [955, 995], [1500, 1530], [1580, 1700], [1730, 1800], [2970, 2985], [2995, 3060], [3075, 3095]]
# [[1630], [1655], [1565], [1610], [1645], [1650], [1685], [1680], [1655], [1650], [1645], [1630], [930], [930], [990], [765], [790]]

# %%
# 烷烃
select_range = [# 烷烃C-H伸缩振动
        [[2975,2950]],
        [[2885,2865],[2940,2915],[2870,2840]],
        [[2890,2880]],
        [[2985,2965],[2955,2935],[2930,2920],[2870,2860],[2830,2740]],
        [
        #[3100,3070],
        [3035,2995]],
        [[3000,2975],[2925,2875]],
        [[2960,2950],[2870,2850]],
        # 烷烃C-H变形振动
        [[1465,1440],[1390,1370]],
        [[1385,1380]],
        [[1370,1365],[1395,1385],[1370,1365]],
        [[1480,1440]],
        [[1340]],
        # [[725,720]],
        # [[735,725]],
        # [[745,735]],
        # [[785,770]],
        # 骨架振动
        # [[1175,1165],[1150,1130],[840,790],[495,490]],
        # [[1255,1245],[1225,1165]],
        # [[510,505]],
        # [[540,485],[455]],
        # [[570,445]],
        # [[560,540],[470,445]],
        # [[555,535]],
        # [[530]],
        # [[490]],
        # [[515]],
        # [[390,260]],
        # [[560,540]],
        # [[545,520]],
        # [[585,565]],
        # [[1030,1000],[870,850],[540,500]],
        # [[1000,960],[930,890],[580,490]],
        # [[1000,960],[930,890],[595,490]],
        # [[1055,1000],[1015,950],[570,435]],
        ## 关联杂原子的C-H伸缩振动
        [[2995,2955],[2900,2865],[2835,2815]],
        [[2995,2955],[2900,2865]],
        [[2820,2760]],
        [[2805,2780]],
        [[2820,2810]],
        [[2825,2810],[2775,2765]],
        [[2830,2800]],
        [[3000,2900]],
        [[3050]],
        [[2820,2710]],
        [[3050,3030]],
        [[3000,2990]],
        [[3050]],
        ## 连于杂原子C-H的变形振动
        [[1470,1430],[1445,1430],[1030]],
        [[1475,1460]],
        [[1470,1435]],
        [[1500,1470]],
        [[1450,1400],[1389,1340]],
        [[1450,1400],[1360,1355]],
        [[1475,1425]],
        [[1435,1405]],
        [[1200]],
        [[1415,1380],[1360,1355],[1500]],
        [[1410,1350]],
        [[1300,1200]],
        [[1440,1400],[1350,1285]],
        [[745,735]],
        [[1440,1390]],
        [[1475,1395]],
        [[1490,1480]],
        [[1420,1405]],
        [[1440]],
        [[1350,1315]],
        [[1480,1450],[1400,1350]],
        [[1425,1415]],
        [[1430,1420]],
        [[1445,1430]],
        [[1435,1385]],
        [[1475]],
        [[1355]],
        [[1305]],
        [[1250]],
        [[1320,1280]],
        [[1325,1300]],
        [[1440,1415]],
        [[1280]],
        [[1460,1405],[1320,1280]],
        [[1265,1250]],
        [[1200,1180]],
        [[1170,1155]],
        [[1265,1240]],
        [[1240,1230]],
        [[1215,1195]],
        [[1165,1145]],
        [[1250]],
        [[1430,1415]],

        ]

# 将range里面的列表重构成一个列表
range_list = []
for item in select_range:
    for sub_item in item:
        # 颠倒顺序
        sub_item.reverse()
        range_list.append(sub_item)

# 取出range_list里面只有一个数的列表，并从range_list里面删除
single_list = []
double_list = []
for item in range_list:
    if len(item) == 1:
        single_list.append(item)
    else:
        double_list.append(item)

print(get_nset_union(double_list))
print(single_list)
# Out:
# [[735, 745], [1145, 1170], [1180, 1500], [2710, 2835], [2840, 3050]]
# [[1340], [3050], [3050], [1030], [1200], [1500], [1440], [1475], [1355], [1305], [1250], [1280], [1250]]

# %%
# 醇
select_range = [# 羟基O-H伸缩振动 
        [[3670,3580]],
        [[3550,3230]],
        [[3590,3400]],
        #[[3200,2500]],
        #[[2780,2400]],
        #[[2700,2500]],
        #[[3200,2500]],
        #[[3600,3100],[1630,1615]],
        #[[3760]],
        #[[3600,3570]],
        #[[3560,3530]],
        #[[3280]],
        #[[3100]],
        #[[2700,2560]],
        ## 羟基O-H变形振动
        [[1350,1260]],
        [[1410,1310]],
        [[700,600]],
        [[1410,1310]],
        [[955,915]],
        [[675]],
        ## 醇C-O伸缩振动
        [[1085,1030]],
        [[1125,1085]],
        [[1205,1125]],
        [[1050]],
        [[1035]],
        [[1020]],
        [[1015]],
        [[1085]],
        [[1070]],
        [[1010]],
        [[1050]],
        [[1135]],
        [[1120]],
        [[1120]],
        [[1060]],
        [[1010]],
        [[1085,1030]],
        [[1125,1085]],
        [[1060,1020]],
        [[1085,1030]],
        [[1260,1180]],
        ## 酚O-H伸缩振动
        # [[3620,3590]],
        # [[3250,3000]],
        # [[3200,2500]],
        ## 酚O-H变形振动和C-O伸缩振动
        # [[1390,1330],[1260,1180]],
        # [[1360,1300],[1225,1150]],
        # [[1320],[1255,1240]],
        # [[1175,1150],[1285,1270],[1190,1180],[1160,1150]],
        # [[1260,1245],[1175,1165]],
        #[[1660],[1110],[720,600],[450,375]],
        ]

# 将range里面的列表重构成一个列表
range_list = []
for item in select_range:
    for sub_item in item:
        # 颠倒顺序
        sub_item.reverse()
        range_list.append(sub_item)

# 取出range_list里面只有一个数的列表，并从range_list里面删除
single_list = []
double_list = []
for item in range_list:
    if len(item) == 1:
        single_list.append(item)
    else:
        double_list.append(item)

print(get_nset_union(double_list))
print(single_list)
# Out:
# [[600, 700], [915, 955], [1020, 1410], [3230, 3670]]
# [[675], [1050], [1035], [1020], [1015], [1085], [1070], [1010], [1050], [1135], [1120], [1120], [1060], [1010]]

# %%
# 碳氢                含氧
[[160, 185], 
[260, 1055], 
[1130, 1530], 
[1575, 1700], 
[1730, 1850], 
[1865, 1900], 
[1970, 1985], 
[2100, 2140], 
[2190, 2270], 
[2710, 2835], 
[2840, 3100], 
[3330, 3340]]

[[375, 450], [470, 515], [600, 720], [750, 770], [785, 1470], [1480, 1900], [2400, 3670]]
