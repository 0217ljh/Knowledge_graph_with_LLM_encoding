# %%
import os
import sys
import yaml
import torch
sys.path.append('../../')
import numpy as np
import pandas as pd
import networkx as nx
from utils import utils
from utils.operation import *
from datetime import datetime
import matplotlib.pyplot as plt
from types import SimpleNamespace
from utils.metrics import select_metric

from Data.data_collect.Merge_collect import Merge_PygDataset
from Data.data_collect.datatype.excel.excel_collect import Excel_PygDataset
from Data.data_collect.datatype.spectrum.spe_collect import Spectrum_PygDataset
from Data.data_collect.datatype.knowledge_map.k_p_collect import Knowledge_graph_PygDataset

#from task_data.graph.graph_task_dataset import MolOFADataset
from task_data.graph.graph_construct import ConstructMolCls
from task_data.eval_data_construct import make_data,make_train_data,make_full_dm_list

from Models.LLM.LLM_Encoder import SentenceEncoder
from Models.models import PyGRGCNEdge,BinGraphModel,BinGraphAttModel


from Light.train import lightning_fit
from Light.data_module import DataModule
from Light.metric import flat_binary_func,EvalKit
from Light.template import ExpConfig,GraphPredLightning
from pytorch_lightning.loggers import WandbLogger
# Out:
# bin C:\Users\ljh\AppData\Roaming\Python\Python310\site-packages\bitsandbytes\libbitsandbytes_cuda116.dll

# %%
task_indicator = 4
dataset_name = 'Small_Molecules'

# %% [markdown]
# # KG

# %%
# 加载知识图谱
Knowledge_graph_loader = Knowledge_graph_PygDataset()
FGD = Knowledge_graph_loader.data_loader('../../Datasets/Knowledge graph(chemistry)/knowledge_graph.gexf','graph')

# %%
# 加载振动信息
addition_information = Excel_PygDataset()
supplement_data = addition_information.data_loader('../../Datasets/Functional group (chemistry)/Functional_group_data_from_wiki_format.xlsx','text')
process_data = addition_information.preprocess()

# %%
# 图数据：FGD.data['1']['Data']
G = FGD.data['1']['Data'].copy()
# 给G添加复数节点：节点的名称为'Functional group{}';可能存在的振动节点；光谱范围节点
# 加入relation关系 ，has'range'
# {}为自然数列，从1开始，每个节点包含'raw_text'和'color'两个属性".
Append_node = []
Append_edge = []
for i in range(len(process_data)):
    # 检测该节点是否存在
    Subtype = ('#' + process_data.loc[i,'Subtype']).replace(' ','')
    core = ''

    dictionary_node = []
    dictionary_edge = []

    G.add_node(f'Range{i+1}',raw_text = process_data.iloc[i]['Range'],color = 'purple')
    dictionary_node.append(process_data.iloc[i]['Range'])
    G.add_node(f'S-Strength{i+1}',raw_text = process_data.iloc[i]['S-Strength'],color = 'yellow')
    dictionary_node.append(process_data.iloc[i]['S-Strength'])

    if process_data.iloc[i]['Functional group']!=None:
        core = ('#' + process_data.loc[i,'Functional group']).replace(' ','')
    else:
        core = Subtype
    if core not in G.nodes:
        G.add_node(core,raw_text = 'feature node. Functional group: <{}>.'.format(core),color = 'cyan')
    else:# 给节点core添加属性
        G.nodes[core]['raw_text'] = 'feature node. Functional group: <{}>.'.format(core)
        G.nodes[core]['color'] = 'cyan'
    if not G.has_edge(core,Subtype):
        G.add_edge(core,Subtype,relation='http://www.w3.org/1999/02/22-rdf-syntax-ns#type',id='2736')
            
    dictionary_node.append(core)

    if not G.has_edge(core,f'Range{i+1}'):
        G.add_edge(core,f'Range{i+1}',relation='feature edge.The absorption peak of this functional group cover the following range')
        dictionary_edge.append('FP-Ran')
    if not G.has_edge(f'Range{i+1}',f'S-Strength{i+1}'):
        G.add_edge(f'Range{i+1}',f'S-Strength{i+1}',relation='feature edge.The vibrational intensity of this absorption peak is as follows')
        dictionary_edge.append('Ran-Str')

    if process_data.iloc[i]['Absorb']!=None and process_data.iloc[i]['Absorb'] not in G.nodes:
        G.add_node(process_data.iloc[i]['Absorb'],raw_text = process_data.iloc[i]['Absorb'],color = 'yellow')
        dictionary_node.append(process_data.iloc[i]['Absorb'])
        if not G.has_edge(f'Range{i+1}',process_data.iloc[i]['Absorb']):
            G.add_edge(f'Range{i+1}',process_data.iloc[i]['Absorb'],relation='feature edge.The type of vibration of this absorption peak is as follows')
            dictionary_edge.append('Ran-Ab')
    elif process_data.iloc[i]['Absorb']!=None and process_data.iloc[i]['Absorb'] in G.nodes:
        dictionary_node.append(process_data.iloc[i]['Absorb'])
        if not G.has_edge(f'Range{i+1}',process_data.iloc[i]['Absorb']):
            G.add_edge(f'Range{i+1}',process_data.iloc[i]['Absorb'],relation='feature edge.The type of vibration of this absorption peak is as follows')
            dictionary_edge.append('Ran-Ab')
    
    Append_node.append(dictionary_node)
    Append_edge.append(dictionary_edge)

# %%
for i in range(len(process_data)):
    nx.relabel_nodes(G,{f'Range{i+1}':process_data.iloc[i]['Range']},copy=False)
FG_graph = G

# %%
sub_graph = nx.generators.ego_graph(FG_graph, '#Phenyl', radius=1,undirected=True)
ppp = sub_graph

plt.rcParams['font.sans-serif'] = ['Simhei']  #显示中文
plt.rcParams['axes.unicode_minus'] = False    #显示负号
pos = nx.spring_layout(ppp)
#colors= [ppp.nodes[n]['color'] for n in ppp.nodes()]
colors = []
for n in ppp.nodes():
    try:colors.append(ppp.nodes[n]['color'])
    except:
        colors.append('brown')
        #print(n)

plt.figure(figsize=(12, 8))
nx.draw(ppp, pos=pos, with_labels=True,font_size=9,node_color=colors)
edge_labels = nx.get_edge_attributes(ppp, 'relatio')
nx.draw_networkx_edge_labels(ppp, pos=pos, edge_labels=edge_labels)
plt.show()

# %% [markdown]
# # Spec

# %%
# 加载光谱信息
Spectrum_loader = Spectrum_PygDataset()
SD = Spectrum_loader.data_loader('G:\Research\数据集\Pper4-Database\Spectral Database')
# SD里面有名字的相关储存
# Out:
# 100%|██████████| 306/306 [00:02<00:00, 120.58it/s]

# %% [markdown]
# ## Label

# %%
# 补充数据掩膜与标签
label = pd.read_excel(r'G:\Research\数据集\Pper4-Database\Task_Set\spect_Task4_语义编码.xlsx')

Meta_Data = {}
for i in range(len(label)):
    meta_data = {}
    meta_data['label'] = label.iloc[i]['标签/双键结构，包括普通双键与芳香族']
    
    Meta_Data[label.iloc[i]['Molecular formula']] = meta_data
Meta_Data = utils.make_mask_proportion(Meta_Data)

# %%
#Meta_Data
# Out:
# {'(C5F9)2': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  '(C6H4)2': {'label': 'Aromatic compound', 'mask': 'valid'},
#  '(CBrF2)2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  '(CCI2F)2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  '(CF2)4': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  '(CF3)2CHOCH2F': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  '(CF3)2CHОCH3': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  '(CF3)2CHОH': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  '(CF3CF2)2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  '(CH2=CH)2': {'label': 'Aromatic compound', 'mask': 'valid'},
#  '(CH2Br)2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  '(CH3)2(CH2)2OC=OCH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  '(CH3)2C=CH(CH2)2C(=CH2)CH=CH2': {'label': 'Aromatic compound',
#   'mask': 'train'},
#  '(CH3)2C=CH(CH2)2C(CH3)=CHCH2OH': {'label': 'Aromatic compound',
#   'mask': 'valid'},
#  '(CH3)2C=CH2': {'label': 'Aromatic compound', 'mask': 'valid'},
#  '(CH3)2C=O': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  '(CH3)2CH(CH2)3OH': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  '(CH3)2CH3C6H5=O': {'label': 'Aromatic compound', 'mask': 'train'},
#  '(CH3)2CHC=OOH': {'label': 'Aromatic compound', 'mask': 'train'},
#  '(CH3)2CHCH2CH3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  '(CH3)2CHCH2CH=O': {'label': 'Aromatic compound', 'mask': 'train'},
#  '(CH3)3CC=OOCH3': {'label': 'Aromatic compound', 'mask': 'test'},
#  '(CH3C=O)2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  '(CH3CH2)2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  '(NH2)2(CH2)2': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  '(S=OF)2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'BrON=O=O': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'C(CI2F)C(F3)': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'C(CI3)C(F3)': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'C(Cl2)=C(CI)C(Cl)=C(CI2)': {'label': 'Aromatic compound', 'mask': 'train'},
#  'C(F3)C(F2)C(F2)ОCH(F)C(F3)': {'label': 'Non-aromatic compound',
#   'mask': 'valid'},
#  'C(F3)C=OOCH2CH=CH2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'C(F3)CH2CH2OH': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'C2H2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'C2H4': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'C2H6': {'label': 'Aromatic compound', 'mask': 'train'},
#  'C2N2': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'C3H6': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'C4H3O(CH2)4CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'C4H3OCH2O': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'C4H4O': {'label': 'Aromatic compound', 'mask': 'train'},
#  'C4OH2(CH3)2(1,3)': {'label': 'Aromatic compound', 'mask': 'train'},
#  'C5Cl2': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'C5H10NH': {'label': 'Aromatic compound', 'mask': 'train'},
#  'C5H4NCH=CH2': {'label': 'Aromatic compound', 'mask': 'train'},
#  'C6F6': {'label': 'Aromatic compound', 'mask': 'train'},
#  'C6H3OH(OCH3)2': {'label': 'Aromatic compound', 'mask': 'test'},
#  'C6H4(CH3)CH2CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'C6H4C2': {'label': 'Aromatic compound', 'mask': 'test'},
#  'C6H4Cl2': {'label': 'Aromatic compound', 'mask': 'train'},
#  'C6H4NH2CH3': {'label': 'Aromatic compound', 'mask': 'test'},
#  'C6H4OHCH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'C6H4OHOCH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'C6H5=CH3(CH3)2CH2(1,5)': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'C6H5C=OOCH2CH3': {'label': 'Aromatic compound', 'mask': 'test'},
#  'C6H5CH2OH': {'label': 'Aromatic compound', 'mask': 'train'},
#  'C6H5CH3': {'label': 'Aromatic compound', 'mask': 'test'},
#  'C6H5CH3C(CH3)2': {'label': 'Aromatic compound', 'mask': 'test'},
#  'C6H5CH=CH2': {'label': 'Aromatic compound', 'mask': 'train'},
#  'C6H5CH=O': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'C6H5Cl': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'C6H5N(CH2)2(CH3)2': {'label': 'Aromatic compound', 'mask': 'test'},
#  'C6H5NO2': {'label': 'Aromatic compound', 'mask': 'train'},
#  'C6H5OH': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'C6H6': {'label': 'Aromatic compound', 'mask': 'test'},
#  'C6H6(CH3)2(1,5)=CH2': {'label': 'Aromatic compound', 'mask': 'train'},
#  'C6H9CH3OHCH(CH3)2': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'C=CH2CH3C6H8OCH3': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'CBr2F2': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CBrCIF2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CBrF3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CCI2F2': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'CCI2FCCIF2': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'CCI3F': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CCIF3': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'CCl3CH2Cl': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'CCl3OH': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CCl4': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'CF2(CH3)2': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'CF2=CF2': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CF2=CFCF=CF2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF2CICCI3': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'CF2CICF2CI': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CF3(CF2)2CH2OH': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3(CF2)2CH=O': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3(CF2)3CF3': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'CF3(CF2)3CH=CH2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3(CF2)3CH=O': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3(CF2)4CF3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3(CF2)4CH2CH2OH': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3(CF2)5CH=CH2': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CF3(CF2)6CF3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3(CF2)6CH2CH2OH': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CF3(CF2)7CH=CH2': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CF3(CF2)8CH2CH2OH': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3C=OOCH2CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CF3C=OOCH=CH2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3CF2C=(O)CF(CF3)2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3CF2CF2CF2OCH2CH3': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'CF3CF2CF3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3CF2CF=CF2': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'CF3CF2CH2O': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3CF2CH2OCH3': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'CF3CF2CH3': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CF3CF2CH=CH2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3CF2CH=O': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3CF2CHF2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3CF2CI': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3CF3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3CF=CF2': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CF3CF=CH2': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CF3CF=CHF(E)': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'CF3CF=CHF(Z)': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3CH2CF3': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CF3CH2CH=O': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3CH2OCH2CF3': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CF3CH2OCH3': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CF3CH2OH': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'CF3CH3': {'label': 'Aromatic compound', 'mask': 'test'},
#  'CF3CH=CH2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3CH=CHF(Z)': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CF3CHFCF2CH2OH': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3CHFCF2OCF3': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'CF3CHFCF2OCH2CH3': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'CF3CHFCF2OCHF2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3CHFCF3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CF3CHFCHFCF2CF3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CF3CHFOCF3': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CF3CHO': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CF3OCF(CF3)CF2OCF2OCF3': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CF3OCF=CF2': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CF3OCH2CH3': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CF4': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CFH2CF3': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CH(BrCI)C(F3)': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH(CH3)(OH)C(CH3)2CH2CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH(CH3)2CH2CH2C=OOH': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH(CH3)3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH(CI2)C(CI2F)': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'CH(CIF)CH(CIF)': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH(Cl2)CH3': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'CH(F2)OCH(CI)CF3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH2=CHC6H4CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH2=CHC=OOCH2CH3': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'CH2=CHCH2CH2CH2OH': {'label': 'Aromatic compound', 'mask': 'test'},
#  'CH2=CHCHОHCH2CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH2=CHCI': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH2=CHCN': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH2=CHF': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH2=CHOCH2CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH2=CHОCH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH2Br2': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CH2BrCl': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CH2CICH2Cl': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH2Cl2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH2FCF2CF3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH2FCH2F': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH2FCH2OH': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'CH2FCHF2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH3(CH2)13CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3(CH2)14CH3': {'label': 'Aromatic compound', 'mask': 'test'},
#  'CH3(CH2)3CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3(CH2)3CH=O': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3(CH2)4CH3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH3(CH2)5CH3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH3(CH2)6CH3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH3(CH2)6CH=CH2': {'label': 'Aromatic compound', 'mask': 'test'},
#  'CH30(CF2)2CF3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH3=OCH2OH': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3C4H3O': {'label': 'Aromatic compound', 'mask': 'test'},
#  'CH3C6H4CH2CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3C6H5C(CH3)2': {'label': 'Aromatic compound', 'mask': 'test'},
#  'CH3C6H8C=CH2(CH3)': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'CH3C6H8C=CH2CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3C=CH2CH=CH2': {'label': 'Aromatic compound', 'mask': 'test'},
#  'CH3C=CH2CH=CH2 (2)': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3C=O(CH2)2CH(CH3)2': {'label': 'Aromatic compound', 'mask': 'test'},
#  'CH3C=O(CH2)2CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3C=O(CH2)6CH3': {'label': 'Aromatic compound', 'mask': 'test'},
#  'CH3C=OCH2C=OOCH3': {'label': 'Aromatic compound', 'mask': 'test'},
#  'CH3C=OCH2CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3C=OCH2COH(CH3)2': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3C=OCH=O': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3C=OO(CH2)5CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3C=OOCH2CH3': {'label': 'Aromatic compound', 'mask': 'test'},
#  'CH3C=OOH': {'label': 'Aromatic compound', 'mask': 'test'},
#  'CH3C=OOONO2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH3CCl3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3CF2CH2CF3': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'CH3CH2CH3': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CH3CH2CH=CH2': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3CH2CH=O': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'CH3CH2F': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH3CH2NHCH2CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3CH2O(CF2)2(CF3)C(F)C(F)(CF3)2': {'label': 'Non-aromatic compound',
#   'mask': 'train'},
#  'CH3CH2OCF2C(F)(CF3)2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH3CH2OH': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3CH=CHCH=O': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3CHF2': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CH3Cl': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3CN': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH3F': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH3l': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH3N=C=S': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3O(CF2CF2O)2CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3O(CF2CF2O)3CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3O(CH2)3CH3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH3OC(F)(CF2CF3)C(F)(CF3)2': {'label': 'Non-aromatic compound',
#   'mask': 'train'},
#  'CH3OC=0CH2CH3': {'label': 'Aromatic compound', 'mask': 'test'},
#  'CH3OC=OC=CH2CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3OC=OCH(CH3)CH2CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3OCF2C(F)(CF3)2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH3OCF2CF2CF3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CH3OCF2CF2OCH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CH3OCF3': {'label': 'Aromatic compound', 'mask': 'test'},
#  'CH3OH': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'CH3SH': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CHBr3': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'CHBrF2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CHCH3NH2(CH2)2CH3': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'CHCI2CF3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CHCI2F': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CHCIF2': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CHCIFCF2CI': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CHCIFCF3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CHCl2CHCl2': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CHCl2OH': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CHCl3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CHF2(CF2)2CF3': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CHF2CF2CH2OCH3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CHF2CF2CH2OH': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CHF2CF3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CHF2CH2CF3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CHF2CH2OH': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CHF2CHF2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CHF2CHFOCF3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CHF2OCF2CF2OCHF2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CHF2OCF2CHFCI': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'CHF2OCF2OCF2CF2OCHF2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CHF2OCF2OCHF2': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CHF2OCF3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CHF2OCH2CF3': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'CHF2OCHFCF3': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'CHF3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CHFCICH2CI': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'CHOHCH3(CH2)3CH3': {'label': 'Aromatic compound', 'mask': 'test'},
#  'CHЗBr': {'label': 'Aromatic compound', 'mask': 'test'},
#  'CICH(Z)=CHCH2CI': {'label': 'Aromatic compound', 'mask': 'test'},
#  'CICH2C=OCH3': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'CICH2CH20CH2CH2C1': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CICH2CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CICH2CHCICH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CICH2OH': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'CICH=CHCH2Cl': {'label': 'Aromatic compound', 'mask': 'train'},
#  'CICH=CHCI': {'label': 'Aromatic compound', 'mask': 'train'},
#  'Cl(CH2)3Cl': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'Cl2C=CCl2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'Cl2C=CHC': {'label': 'Aromatic compound', 'mask': 'train'},
#  'Cl2CHCH2CI': {'label': 'Aromatic compound', 'mask': 'train'},
#  'FC(CF2)4CF(CF2)4': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'FCH2F': {'label': 'Aromatic compound', 'mask': 'test'},
#  'GeH4': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'HCOOH': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'ICH2CH3': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'lCH2l': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'm-C6H4(CH3)2': {'label': 'Aromatic compound', 'mask': 'train'},
#  'N(CF2)9(CF3)3': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'N(CH2CH3)2CH=O': {'label': 'Aromatic compound', 'mask': 'train'},
#  'N(CH2CH3)3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'N(CH3)3': {'label': 'Aromatic compound', 'mask': 'test'},
#  'NH(CH(CH3)2)2': {'label': 'Aromatic compound', 'mask': 'train'},
#  'NH(CH3)2': {'label': 'Aromatic compound', 'mask': 'train'},
#  'NH2(CH2)3CH3': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'NH2CH2CH3': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'NH=C=O': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'NHCH2CHCH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'O(CH3)2': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'o-C6H4(CH3)2': {'label': 'Aromatic compound', 'mask': 'test'},
#  'O2C3H3=OCH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'O2NONO2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'O=CHCH=CH2': {'label': 'Aromatic compound', 'mask': 'test'},
#  'O=CHCH=O': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'O=CHOH': {'label': 'Aromatic compound', 'mask': 'train'},
#  'O=CHОCH2CHЗ': {'label': 'Aromatic compound', 'mask': 'train'},
#  'O=N=OOOH': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'O=NOCH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'O=S=O(O2)(CH3)2': {'label': 'Aromatic compound', 'mask': 'train'},
#  'OC4H3CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'OC4H3CH=O': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'OC5H5(CH2)2CH3(CH3)2': {'label': 'Aromatic compound', 'mask': 'train'},
#  'OH(CH2CH3)2': {'label': 'Aromatic compound', 'mask': 'test'},
#  'OHC6H4C=OOCH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'OHC6H4OCH3': {'label': 'Aromatic compound', 'mask': 'test'},
#  'OHC=O(CH2)3CH3': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'OHC=O(CH2)6CH3': {'label': 'Aromatic compound', 'mask': 'train'},
#  'OHC=OCF3': {'label': 'Aromatic compound', 'mask': 'test'},
#  'OHC=OCH=CH2': {'label': 'Aromatic compound', 'mask': 'train'},
#  'OHCH((CH2)3CH3)2': {'label': 'Aromatic compound', 'mask': 'train'},
#  'OHCH2CH=O': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'S(CH3)2': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'S2(CH3)2': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'S=O(CH3)2': {'label': 'Aromatic compound', 'mask': 'valid'},
#  'SF5CF3': {'label': 'Non-aromatic compound', 'mask': 'train'},
#  'SiH4': {'label': 'Non-aromatic compound', 'mask': 'valid'},
#  'trans-CF3CH=CHCI': {'label': 'Non-aromatic compound', 'mask': 'test'},
#  'C4OH2(CH3)2(1,2)': {'label': 'Aromatic compound', 'mask': 'train'}}

# %%
spectrum_dataset = Spectrum_loader.preprocess(SD.data)
Spectrum_graph = Spectrum_loader.construct_graph(spectrum_dataset,get_standrd_meta,kwargs=Meta_Data)

# %%
#Spectrum_loader.graph_visualisation(Spectrum_graph['(C6H4)2']['graph'])

# %% [markdown]
# # Save

# %%
# import pickle
# # 保存Spectrum_graph文件
# with open(f'../../Datasets/Data_for_different_task/Task{task_indicator}/{dataset_name}/Spectrum_graph.pkl', 'wb') as f:
#     pickle.dump(Spectrum_graph, f)
# # 保存FG_graph文件
# with open(f'../../Datasets/Data_for_different_task/Task{task_indicator}/{dataset_name}/FG_graph.pkl', 'wb') as f:
#     pickle.dump(FG_graph, f)

# %% [markdown]
# # Merge(used for pyg)

# %%
test_class = Merge_PygDataset(FG_graph,Spectrum_graph['(C6H4)2'], Name = '(C6H4)2')
connected_dictionary = test_class.preprocess()
all_Table,isexist,score_dict = test_class.Negative_relevant_information(is_print=False)
OP = test_class.construct_graph(connected_dictionary,all_Table,is_print=False)
fin = test_class.subgraph_extraction(hop=2)

# %%
#test_class.graph_visualisation(fin)
