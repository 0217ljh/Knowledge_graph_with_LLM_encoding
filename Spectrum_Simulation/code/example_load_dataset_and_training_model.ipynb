# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from detanet_model import *
from torch_geometric.loader import DataLoader

# %%
'''First, the pytorch library can be used to load the dataset, which consists of 130K molecules, after importing the pytorch library.'''
dataset=torch.load('../data/qm9s.pt')

len(dataset)

# %%
'''where each molecule is a gemetric.data.Data. containing coordinates, atomic numbers, edge indices, and various properties.'''
dataset[9996]

# %%
'''We divided the dataset evenly and used 5% of the data for testing and other for training:'''
train_datasets=[]
val_datasets=[]
for i in range(0,3500):
    if i%5==0:
        val_datasets.append(dataset[i])
    else:
        train_datasets.append(dataset[i])
len(train_datasets),len(val_datasets)

# %%
# import torch
# from LLM_preprocess import process_data_with_llm_edge

# # 假设 dataset 已经定义好
# train_datasets = []
# val_datasets = []

# # 将数据分为训练集和验证集
# for i in range(len(dataset)):
#     if i % 10 == 0:
#         val_datasets.append(dataset[i])
#     else:
#         train_datasets.append(dataset[i])

# # 分段保存数据，每5000条处理一次
# def process_and_save_in_batches(data, filename_prefix, batch_size=5000, start_batch=0):
#     total_batches = (len(data) + batch_size - 1) // batch_size  # 计算批次数
#     for batch_num in range(start_batch, total_batches):
#         start_idx = batch_num * batch_size
#         end_idx = min((batch_num + 1) * batch_size, len(data))  # 确保索引不超出数据范围
#         batch_data = data[start_idx:end_idx]
        
#         # 调用 LLM 提取边特征
#         edge_data = process_data_with_llm_edge(batch_data, llm_model_name="bert-base-uncased", device='cuda', grad=None)
        
#         # 保存为 pt 文件
#         torch.save(edge_data, f'{filename_prefix}_edge_batch_{batch_num+1}.pt')
#         print(f"Batch {batch_num+1}/{total_batches} saved to {filename_prefix}_edge_batch_{batch_num+1}.pt")

# # 从第二个 batch 开始处理并保存训练集和验证集
# process_and_save_in_batches(train_datasets, 'train', batch_size=1000, start_batch=15)  # 从第 2 个 batch 开始
# process_and_save_in_batches(val_datasets, 'val', batch_size=1000,start_batch=2)  # 可以选择从第 1 个 batch 开始

# %%
# import torch

# a=torch.load('F:\\Code\\Spectrum simulation\\code\\train_edge_batch_1(o).pt')
# print(a[1])

# # 加载单个批次的数据集文件
# batch_file = 'F:\\Code\\Spectrum simulation\\code\\val_edge_batch_1.pt'  # 替换为你要处理的实际文件名
# edge_data = torch.load(batch_file)  # 加载数据

# # 创建 mijs2 和 mijs 两个列表
# mijs2_list = []
# mijs_list = []

# # 提取 mijs2 和 mijs 字段
# for edge in edge_data:
#     mijs2_list.append(edge[0])  # 假设每个 edge 中的第一个元素是 mijs2
#     mijs_list.append(edge[1])  # 假设每个 edge 中的第二个元素是 mijs

# # 将 mijs2 和 mijs 列表保存为 .pt 文件，方便后续使用
# torch.save(mijs2_list, 'Valid_mijs2(1-5000).pt')
# torch.save(mijs_list, 'Valid_mijs(1-5000).pt')

# print("mijs2 and mijs lists have been saved to 'mijs2_list.pt' and 'mijs_list.pt'.")

# %%
# Train_mijs=torch.load('F:\\Code\\Spectrum simulation\\code\\Train_mijs(1-5000).pt')
# Train_mijs2=torch.load('F:\\Code\\Spectrum simulation\\code\\Train_mijs2(1-5000).pt')
# Val_mijs=torch.load('F:\\Code\\Spectrum simulation\\code\\Valid_mijs(1-5000).pt')
# Val_mijs2=torch.load('F:\\Code\\Spectrum simulation\\code\\Valid_mijs2(1-5000).pt')

# %%
'''Using torch_Geometric.dataloader.DataLoader Converts a dataset into a batch of 64 molecules of training data.'''
bathes=32
trainloader=DataLoader(train_datasets,batch_size=bathes,shuffle=True)
valloader=DataLoader(val_datasets,batch_size=bathes,shuffle=True)

# %%
from huggingface_hub import login

# token = "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"
# login(token=token)

'''After loading the dataset, we train a model using NPA charge as an example.
 	Firstly, construct an untrained model:'''

model = DetaNet(num_features=40,
                 act='swish',
                 maxl=3,
                 num_block=1,
                 radial_type='trainable_bessel',
                 num_radial=32,
                 attention_head=8,
                 rc=5.0,
                 dropout=0.0,
                 use_cutoff=False,
                 max_atomic_number=9,
                 atom_ref=None,
                 scale=1.0,
                 scalar_outsize=1,
                 irreps_out='1o',
                 summation=False,
                 norm=False,
                 out_type='dipole',
                 grad_type='dipole',
                 device=torch.device('cuda'))
model.train()

# %%
class Trainer:
    def __init__(self, model, train_loader, val_loader=None, loss_function=l2loss, device=torch.device('cuda'),
                 optimizer='Adam_amsgrad', lr=5e-4, weight_decay=0):
        self.opt_type = optimizer
        self.device = device
        self.model = model
        self.train_data = train_loader
        self.val_data = val_loader
        self.device = device
        self.opts = {
            'AdamW': torch.optim.AdamW(self.model.parameters(), lr=lr, amsgrad=False, weight_decay=weight_decay),
            'AdamW_amsgrad': torch.optim.AdamW(self.model.parameters(), lr=lr, amsgrad=True, weight_decay=weight_decay),
            'Adam': torch.optim.Adam(self.model.parameters(), lr=lr, amsgrad=False, weight_decay=weight_decay),
            'Adam_amsgrad': torch.optim.Adam(self.model.parameters(), lr=lr, amsgrad=True, weight_decay=weight_decay),
            'Adadelta': torch.optim.Adadelta(self.model.parameters(), lr=lr, weight_decay=weight_decay),
            'RMSprop': torch.optim.RMSprop(self.model.parameters(), lr=lr, weight_decay=weight_decay),
            'SGD': torch.optim.SGD(self.model.parameters(), lr=lr, weight_decay=weight_decay)
        }
        self.optimizer = self.opts[self.opt_type]
        self.loss_function = loss_function
        self.step = -1

    def train(self, num_train, targ, stop_loss=1e-8, val_per_train=5, print_per_epoch=1, max_grad_norm=2.0):
        self.model.train()
        len_train = len(self.train_data)
        
        # Loop through training epochs
        for i in range(num_train):
            val_datas = iter(self.val_data) if self.val_data else None
            
            for j, batch in enumerate(self.train_data):
                self.step += 1
                torch.cuda.empty_cache()
                self.optimizer.zero_grad()
                
                # Forward pass for the training batch
                out = self.model(pos=batch.pos.to(self.device), z=batch.z.to(self.device),
                                 batch=batch.batch.to(self.device))
                target = batch[targ].to(self.device)
                loss = self.loss_function(out.reshape(target.shape), target)
                
                # Backward pass
                loss.backward()
                
                # 梯度裁剪
                torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_grad_norm)
                
                # 更新参数
                self.optimizer.step()

                # Calculate train R² value for the batch
                train_R2 = R2(out.reshape(target.shape), target).item()

                # Validation step
                if (self.step % val_per_train == 0) and (self.val_data is not None):
                    val_batch = next(val_datas)
                    val_target = val_batch[targ].to(self.device).reshape(-1)
                    val_out = self.model(pos=val_batch.pos.to(self.device), z=val_batch.z.to(self.device),
                                         batch=val_batch.batch.to(self.device)).reshape(val_target.shape)
                    
                    # Validation loss and metrics
                    val_loss = self.loss_function(val_out, val_target).item()
                    val_mae = l1loss(val_out, val_target).item()
                    val_R2 = R2(val_out, val_target).item()
                    
                    # Print training loss and metrics
                    if self.step % print_per_epoch == 0:
                        print('Epoch[{}/{}], loss: {:.8f}, train_R2: {:.8f}, val_loss: {:.8f}, val_mae: {:.8f}, val_R2: {:.8f}'
                              .format(self.step, num_train * len_train, loss.item(), train_R2, val_loss, val_mae, val_R2))

                    # Early stopping condition
                    assert (loss > stop_loss) or (val_loss > stop_loss), 'Training or validation loss below cutoff, stopping training.'
                
                # Print only training loss if no validation
                elif (self.step % print_per_epoch == 0):
                    print('Epoch[{}/{}], loss: {:.8f}, train_R2: {:.8f}'
                          .format(self.step, num_train * len_train, loss.item(), train_R2))

    def load_state_and_optimizer(self, state_path=None, optimizer_path=None):
        if state_path is not None:
            state_dict = torch.load(state_path)
            self.model.load_state_dict(state_dict)
        if optimizer_path is not None:
            self.optimizer = torch.load(optimizer_path)

    def save_param(self, path):
        torch.save(self.model.state_dict(), path)

    def save_model(self, path):
        torch.save(self.model, path)

    def save_opt(self, path):
        torch.save(self.optimizer, path)

    def params(self):
        return self.model.state_dict()

# %%
'''Then, modify the data type and device type'''
device=torch.device('cuda')
dtype=torch.float32
model=model.to(dtype)
model=model.to(device)

# %%
'''Finally, using the trainer, training 20 times from a 5e-4 learning rate'''
trainer=Trainer(model,train_loader=trainloader,val_loader=valloader,loss_function=l2loss,lr=1e-7,weight_decay=0,optimizer='AdamW')

# %%
trainer.train(num_train=1,targ='dedipole')

# %%
'''After the training is completed, take out the learnable parameters and save them as a. pth file.'''
state_dict=model.state_dict
state_dict()

# %%
torch.save(model.state_dict(),'trained_param/LLM_Test/dedippole.pth')

# %%
'''When needed model , simply load parameters on the untrained model. The parameters we have trained are saved in trained_Param/.'''
state_dict=torch.load('trained_param/LLM_Test/Hi.pth')
model.load_state_dict(state_dict)
